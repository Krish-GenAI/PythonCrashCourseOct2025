# %%
## Basics of Python

Datatypes of Python
Variables
Variable Assignment
Print Statements

# %% [markdown]
# ## Check the data types

# %%
type(1)
# Out:
# int

# %%
type('Hello, World!')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Mathematical Operations with variable assignment

# %%
a = 10
b = 20

# %%
print(a*b)
print(a+b)
# Out:
# 200
# 30

# %%
print("Addiing {} and {} gives {}".format(a, b, a+b))
# Out:
# Addiing 10 and 20 gives 30

# %%
len('Krishna')
# Out:
# 7

# %%
type([1, 2, 3, 4, 5])
# Out:
# list
